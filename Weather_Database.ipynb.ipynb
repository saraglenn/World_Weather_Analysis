# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# !pip install config
# Out:
# Collecting config
#   Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.1

# %%
import config

# %%
import requests
requests.__version__
# Out:
# '2.28.1'

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import requests
from citipy import citipy
import time
from datetime import datetime

# %%
# %pwd
# Out:
# 'C:\\Users\\scath\\World_Weather_Analysis\\Weather_Database'

# %%
from config import op_weath_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10304\2996960410.py in <module>
# ----> 1 from config import op_weath_key
#
# ImportError: cannot import name 'op_weath_key' from 'config' (C:\Users\scath\World_Weather_Analysis\Weather_Database\config.py)

# %%
op_weath_key = '5e96f533b3f8f5d11bbf60f0b674c97b'

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + op_weath_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5e96f533b3f8f5d11bbf60f0b674c97b

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city_obj = citipy.nearest_city(coordinate[0], coordinate[1])
    city = city_obj.city_name + "," + city_obj.country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 733

# %%
# print the first 10 cities
cities[0:10]
# Out:
# ['tiksi,ru',
#  'albany,au',
#  'usogorsk,ru',
#  'tsiombe,mg',
#  'port-aux-francais,tf',
#  'ciudad lazaro cardenas,mx',
#  'dudinka,ru',
#  'edinburgh of the seven seas,sh',
#  'ushuaia,ar',
#  'grytviken,gs']

# %%
# print the last 10 cities
cities[-10:len(cities)]
# Out:
# ['gizo,sb',
#  'mulayjah,sa',
#  'sedan,fr',
#  'jumla,np',
#  'debre sina,et',
#  'sungho 1-tong,kp',
#  'new plymouth,nz',
#  'bafoulabe,ml',
#  'reggane,dz',
#  'kalamunda,au']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# already imported
# Import the requests library
# import requests

# Import the time library
# import time

# Import the datetime module from the datetime library
# from datetime import datetime

# Import the OpenWeatherMap's API key
from config import op_weath_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10304\2671741762.py in <module>
#      10
#      11 # Import the OpenWeatherMap's API key
# ---> 12 from config import op_weath_key
#
# ImportError: cannot import name 'op_weath_key' from 'config' (C:\Users\scath\World_Weather_Analysis\Weather_Database\config.py)

# %%
op_weath_key = "5e96f533b3f8f5d11bbf60f0b674c97b"

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?" + f"appid={op_weath_key}" + "&units=imperial"

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_data.append({
            "City" : city_weather['name'],
            "Lat" : city_weather['coord']['lat'],
            "Lng" : city_weather['coord']['lon'],
            "Max Temp" : city_weather['main']['temp_max'],
            "Current Description" : city_weather['weather'][0]['description'],
            "Humidity" : city_weather["main"]["humidity"],
            "Cloudiness" : city_weather["clouds"]["all"],
            "Wind Speed" : city_weather["wind"]["speed"],
            "Country" : city_weather["sys"]["country"]
        })      
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except (IndexError, KeyError):
        print(f"City {city} not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi,ru
# Processing Record 2 of Set 1 | albany,au
# Processing Record 3 of Set 1 | usogorsk,ru
# Processing Record 4 of Set 1 | tsiombe,mg
# Processing Record 5 of Set 1 | port-aux-francais,tf
# Processing Record 6 of Set 1 | ciudad lazaro cardenas,mx
# Processing Record 7 of Set 1 | dudinka,ru
# Processing Record 8 of Set 1 | edinburgh of the seven seas,sh
# Processing Record 9 of Set 1 | ushuaia,ar
# Processing Record 10 of Set 1 | grytviken,gs
# Processing Record 11 of Set 1 | san antonio de pale,gq
# Processing Record 12 of Set 1 | mili,mh
# Processing Record 13 of Set 1 | eberswalde,de
# Processing Record 14 of Set 1 | bethel,us
# Processing Record 15 of Set 1 | tshabong,bw
# Processing Record 16 of Set 1 | susuman,ru
# Processing Record 17 of Set 1 | papatowai,nz
# Processing Record 18 of Set 1 | sale,au
# Processing Record 19 of Set 1 | iqaluit,ca
# Processing Record 20 of Set 1 | plesetsk,ru
# Processing Record 21 of Set 1 | waitangi,nz
# Processing Record 22 of Set 1 | blackmans bay,au
# Processing Record 23 of Set 1 | touros,br
# Processing Record 24 of Set 1 | kodiak,us
# Processing Record 25 of Set 1 | avarua,ck
# Processing Record 26 of Set 1 | hohhot,cn
# Processing Record 27 of Set 1 | moranbah,au
# Processing Record 28 of Set 1 | georgetown,sh
# Processing Record 29 of Set 1 | port alfred,za
# Processing Record 30 of Set 1 | rongelap,mh
# Processing Record 31 of Set 1 | isafjordur,is
# Processing Record 32 of Set 1 | atafu village,tk
# Processing Record 33 of Set 1 | minas de marcona,pe
# Processing Record 34 of Set 1 | xinji,cn
# Processing Record 35 of Set 1 | tura,ru
# Processing Record 36 of Set 1 | ilulissat,gl
# Processing Record 37 of Set 1 | yarmouth,ca
# Processing Record 38 of Set 1 | port saint john's,za
# Processing Record 39 of Set 1 | yellowknife,ca
# Processing Record 40 of Set 1 | bayanhongor,mn
# Processing Record 41 of Set 1 | pimenta bueno,br
# Processing Record 42 of Set 1 | baixa grande,br
# Processing Record 43 of Set 1 | katsuura,jp
# Processing Record 44 of Set 1 | whitehorse,ca
# Processing Record 45 of Set 1 | gatesville,us
# Processing Record 46 of Set 1 | bredasdorp,za
# Processing Record 47 of Set 1 | adamstown,pn
# Processing Record 48 of Set 1 | saipan,mp
# Processing Record 49 of Set 1 | rameswaram,in
# Processing Record 50 of Set 1 | kone,nc
# Processing Record 1 of Set 2 | margaret river,au
# Processing Record 2 of Set 2 | puerto ayora,ec
# Processing Record 3 of Set 2 | mhamid,ma
# Processing Record 4 of Set 2 | cidreira,br
# Processing Record 5 of Set 2 | puerto natales,cl
# Processing Record 6 of Set 2 | tranovaho,mg
# City tranovaho,mg not found. Skipping...
# Processing Record 7 of Set 2 | chazuta,pe
# Processing Record 8 of Set 2 | ahau,fj
# City ahau,fj not found. Skipping...
# Processing Record 9 of Set 2 | lihue,us
# Processing Record 10 of Set 2 | sinabang,id
# Processing Record 11 of Set 2 | veraval,in
# Processing Record 12 of Set 2 | punta arenas,cl
# Processing Record 13 of Set 2 | cabo san lucas,mx
# Processing Record 14 of Set 2 | vicosa do ceara,br
# Processing Record 15 of Set 2 | stanley,fk
# Processing Record 16 of Set 2 | west island,cc
# Processing Record 17 of Set 2 | chonchi,cl
# Processing Record 18 of Set 2 | klaksvik,fo
# Processing Record 19 of Set 2 | mugia,es
# Processing Record 20 of Set 2 | selfoss,is
# Processing Record 21 of Set 2 | east london,za
# Processing Record 22 of Set 2 | island harbour,ai
# City island harbour,ai not found. Skipping...
# Processing Record 23 of Set 2 | atamyrat,tm
# Processing Record 24 of Set 2 | el porvenir,pa
# Processing Record 25 of Set 2 | tolanaro,mg
# Processing Record 26 of Set 2 | praia da vitoria,pt
# Processing Record 27 of Set 2 | conception bay south,ca
# Processing Record 28 of Set 2 | keflavik,is
# Processing Record 29 of Set 2 | invercargill,nz
# Processing Record 30 of Set 2 | jamestown,sh
# Processing Record 31 of Set 2 | codrington,ag
# City codrington,ag not found. Skipping...
# Processing Record 32 of Set 2 | sandpoint,us
# Processing Record 33 of Set 2 | bilibino,ru
# Processing Record 34 of Set 2 | wailua homesteads,us
# Processing Record 35 of Set 2 | luderitz,na
# Processing Record 36 of Set 2 | vila franca do campo,pt
# Processing Record 37 of Set 2 | nuuk,gl
# Processing Record 38 of Set 2 | anadyr,ru
# Processing Record 39 of Set 2 | caucasia,co
# Processing Record 40 of Set 2 | khovd,mn
# Processing Record 41 of Set 2 | gadzhiyevo,ru
# Processing Record 42 of Set 2 | bam,ir
# Processing Record 43 of Set 2 | arkhangel'sk,ru
# Processing Record 44 of Set 2 | ban nam yuen,th
# Processing Record 45 of Set 2 | klyuchi,ru
# Processing Record 46 of Set 2 | vanino,ru
# Processing Record 47 of Set 2 | sola,vu
# Processing Record 48 of Set 2 | bulawayo,zw
# Processing Record 49 of Set 2 | taiohae,pf
# City taiohae,pf not found. Skipping...
# Processing Record 50 of Set 2 | devinuwara,lk
# City devinuwara,lk not found. Skipping...
# Processing Record 1 of Set 3 | soe,id
# Processing Record 2 of Set 3 | nemuro,jp
# Processing Record 3 of Set 3 | belozersk,ru
# Processing Record 4 of Set 3 | college,us
# Processing Record 5 of Set 3 | port elizabeth,za
# Processing Record 6 of Set 3 | santo antonio,st
# Processing Record 7 of Set 3 | morondava,mg
# Processing Record 8 of Set 3 | petropavlovsk-kamchatsky,ru
# Processing Record 9 of Set 3 | chibougamau,ca
# Processing Record 10 of Set 3 | longyearbyen,sj
# Processing Record 11 of Set 3 | kupang,id
# Processing Record 12 of Set 3 | novoleushkovskaya,ru
# Processing Record 13 of Set 3 | geraldton,au
# Processing Record 14 of Set 3 | lautoka,fj
# Processing Record 15 of Set 3 | olonkinbyen,sj
# Processing Record 16 of Set 3 | ocean city,us
# Processing Record 17 of Set 3 | xining,cn
# Processing Record 18 of Set 3 | tymovskoye,ru
# Processing Record 19 of Set 3 | les cayes,ht
# Processing Record 20 of Set 3 | alofi,nu
# Processing Record 21 of Set 3 | tatarsk,ru
# Processing Record 22 of Set 3 | slupsk,pl
# Processing Record 23 of Set 3 | kamina,cd
# Processing Record 24 of Set 3 | lebu,cl
# Processing Record 25 of Set 3 | jining,cn
# Processing Record 26 of Set 3 | pacific grove,us
# Processing Record 27 of Set 3 | bamboo flat,in
# Processing Record 28 of Set 3 | nova olimpia,br
# Processing Record 29 of Set 3 | hamilton,bm
# Processing Record 30 of Set 3 | thompson,ca
# Processing Record 31 of Set 3 | enewetak,mh
# Processing Record 32 of Set 3 | udon thani,th
# Processing Record 33 of Set 3 | talnakh,ru
# Processing Record 34 of Set 3 | twon-brass,ng
# Processing Record 35 of Set 3 | vorgashor,ru
# Processing Record 36 of Set 3 | valle de la pascua,ve
# Processing Record 37 of Set 3 | joshimath,in
# Processing Record 38 of Set 3 | verkhnyaya sinyachikha,ru
# Processing Record 39 of Set 3 | 'ohonua,to
# City 'ohonua,to not found. Skipping...
# Processing Record 40 of Set 3 | polyarnyy,ru
# Processing Record 41 of Set 3 | ancud,cl
# Processing Record 42 of Set 3 | kingston,nf
# Processing Record 43 of Set 3 | egilsstadir,is
# Processing Record 44 of Set 3 | phang nga,th
# Processing Record 45 of Set 3 | maragogi,br
# Processing Record 46 of Set 3 | bazou,cm
# Processing Record 47 of Set 3 | hadibu,ye
# Processing Record 48 of Set 3 | hammerfest,no
# Processing Record 49 of Set 3 | lazaro cardenas,mx
# Processing Record 50 of Set 3 | magadan,ru
# Processing Record 1 of Set 4 | tarawa,ki
# Processing Record 2 of Set 4 | rio hato,pa
# Processing Record 3 of Set 4 | santa rita,py
# Processing Record 4 of Set 4 | la ronge,ca
# Processing Record 5 of Set 4 | christchurch,nz
# Processing Record 6 of Set 4 | la passe,sc
# City la passe,sc not found. Skipping...
# Processing Record 7 of Set 4 | thal,pk
# Processing Record 8 of Set 4 | zhuanghe,cn
# Processing Record 9 of Set 4 | acarau,br
# Processing Record 10 of Set 4 | sitka,us
# Processing Record 11 of Set 4 | queenstown,nz
# Processing Record 12 of Set 4 | lospalos,tl
# Processing Record 13 of Set 4 | hihifo,to
# City hihifo,to not found. Skipping...
# Processing Record 14 of Set 4 | roswell,us
# Processing Record 15 of Set 4 | aasiaat,gl
# Processing Record 16 of Set 4 | arzgir,ru
# Processing Record 17 of Set 4 | tarancon,es
# Processing Record 18 of Set 4 | bathsheba,bb
# Processing Record 19 of Set 4 | chifeng,cn
# Processing Record 20 of Set 4 | saint-joseph,re
# Processing Record 21 of Set 4 | isangel,vu
# Processing Record 22 of Set 4 | santo antonio do ica,br
# Processing Record 23 of Set 4 | gurupa,br
# Processing Record 24 of Set 4 | fallon,us
# Processing Record 25 of Set 4 | fale old settlement,tk
# Processing Record 26 of Set 4 | hermanus,za
# Processing Record 27 of Set 4 | iranshahr,ir
# Processing Record 28 of Set 4 | urangan,au
# Processing Record 29 of Set 4 | kenai,us
# Processing Record 30 of Set 4 | tonghae,kr
# Processing Record 31 of Set 4 | padang,id
# Processing Record 32 of Set 4 | yung shue wan,hk
# Processing Record 33 of Set 4 | daru,pg
# Processing Record 34 of Set 4 | vadso,no
# Processing Record 35 of Set 4 | calama,cl
# Processing Record 36 of Set 4 | kangar,my
# Processing Record 37 of Set 4 | luwingu,zm
# Processing Record 38 of Set 4 | puerto san carlos,mx
# City puerto san carlos,mx not found. Skipping...
# Processing Record 39 of Set 4 | oriximina,br
# Processing Record 40 of Set 4 | uturoa,pf
# Processing Record 41 of Set 4 | tobi village,pw
# City tobi village,pw not found. Skipping...
# Processing Record 42 of Set 4 | saldanha,za
# Processing Record 43 of Set 4 | valparaiso,cl
# Processing Record 44 of Set 4 | juazeirinho,br
# Processing Record 45 of Set 4 | tezu,in
# Processing Record 46 of Set 4 | alotau,pg
# City alotau,pg not found. Skipping...
# Processing Record 47 of Set 4 | toliara,mg
# Processing Record 48 of Set 4 | greymouth,nz
# Processing Record 49 of Set 4 | tianchang,cn
# Processing Record 50 of Set 4 | kyzyl,ru
# Processing Record 1 of Set 5 | naze,jp
# Processing Record 2 of Set 5 | kaga bandoro,cf
# Processing Record 3 of Set 5 | nacala,mz
# Processing Record 4 of Set 5 | antofagasta,cl
# Processing Record 5 of Set 5 | la sarre,ca
# Processing Record 6 of Set 5 | fuvahmulah,mv
# City fuvahmulah,mv not found. Skipping...
# Processing Record 7 of Set 5 | fort mcmurray,ca
# Processing Record 8 of Set 5 | ulubey,tr
# Processing Record 9 of Set 5 | axim,gh
# Processing Record 10 of Set 5 | whitburn,gb
# Processing Record 11 of Set 5 | kalmunai,lk
# Processing Record 12 of Set 5 | holualoa,us
# Processing Record 13 of Set 5 | vargashi,ru
# Processing Record 14 of Set 5 | korla,cn
# Processing Record 15 of Set 5 | udachny,ru
# Processing Record 16 of Set 5 | binzhou,cn
# Processing Record 17 of Set 5 | kill devil hills,us
# Processing Record 18 of Set 5 | zhanibek,kz
# Processing Record 19 of Set 5 | rabka-zdroj,pl
# Processing Record 20 of Set 5 | afaahiti,pf
# Processing Record 21 of Set 5 | diffa,ne
# Processing Record 22 of Set 5 | port mathurin,mu
# Processing Record 23 of Set 5 | berezovyy,ru
# Processing Record 24 of Set 5 | pisco,pe
# Processing Record 25 of Set 5 | san fernando,mx
# Processing Record 26 of Set 5 | tralee,ie
# Processing Record 27 of Set 5 | eger,hu
# Processing Record 28 of Set 5 | bengaluru,in
# Processing Record 29 of Set 5 | malango,sb
# City malango,sb not found. Skipping...
# Processing Record 30 of Set 5 | boa vista,br
# Processing Record 31 of Set 5 | dalai,cn
# Processing Record 32 of Set 5 | belyy yar,ru
# Processing Record 33 of Set 5 | kapuskasing,ca
# Processing Record 34 of Set 5 | lagos,pt
# Processing Record 35 of Set 5 | takamaka,sc
# City takamaka,sc not found. Skipping...
# Processing Record 36 of Set 5 | sinan,kr
# Processing Record 37 of Set 5 | hawaiian paradise park,us
# Processing Record 38 of Set 5 | todos santos,mx
# Processing Record 39 of Set 5 | yeppoon,au
# Processing Record 40 of Set 5 | vilyuchinsk,ru
# Processing Record 41 of Set 5 | es castell,es
# Processing Record 42 of Set 5 | utrik,mh
# Processing Record 43 of Set 5 | tazovsky,ru
# Processing Record 44 of Set 5 | fort st. john,ca
# Processing Record 45 of Set 5 | altai,mn
# Processing Record 46 of Set 5 | levuka,fj
# City levuka,fj not found. Skipping...
# Processing Record 47 of Set 5 | ujae,mh
# Processing Record 48 of Set 5 | hirara,jp
# Processing Record 49 of Set 5 | kavieng,pg
# Processing Record 50 of Set 5 | tyuratam,kz
# Processing Record 1 of Set 6 | nar'yan-mar,ru
# Processing Record 2 of Set 6 | broome,au
# Processing Record 3 of Set 6 | mwingi,ke
# Processing Record 4 of Set 6 | oneida,us
# Processing Record 5 of Set 6 | adis zemen,et
# Processing Record 6 of Set 6 | vilshofen,de
# Processing Record 7 of Set 6 | shangrao,cn
# Processing Record 8 of Set 6 | vredenburg,za
# City vredenburg,za not found. Skipping...
# Processing Record 9 of Set 6 | nouadhibou,mr
# Processing Record 10 of Set 6 | belidzhi,ru
# Processing Record 11 of Set 6 | makhambet,kz
# Processing Record 12 of Set 6 | suez,eg
# Processing Record 13 of Set 6 | nabire,id
# Processing Record 14 of Set 6 | kabansk,ru
# Processing Record 15 of Set 6 | cozumel,mx
# Processing Record 16 of Set 6 | cururupu,br
# Processing Record 17 of Set 6 | al 'aziziyah,iq
# Processing Record 18 of Set 6 | nerchinsk,ru
# Processing Record 19 of Set 6 | caleta de carquin,pe
# Processing Record 20 of Set 6 | cauto cristo,cu
# City cauto cristo,cu not found. Skipping...
# Processing Record 21 of Set 6 | formosa do rio preto,br
# Processing Record 22 of Set 6 | ribeira grande,cv
# Processing Record 23 of Set 6 | palafrugell,es
# Processing Record 24 of Set 6 | kirensk,ru
# Processing Record 25 of Set 6 | aktau,kz
# Processing Record 26 of Set 6 | neiafu,to
# Processing Record 27 of Set 6 | maqat,kz
# Processing Record 28 of Set 6 | tadine,nc
# Processing Record 29 of Set 6 | richards bay,za
# Processing Record 30 of Set 6 | remire-montjoly,gf
# Processing Record 31 of Set 6 | terrace,ca
# Processing Record 32 of Set 6 | belmonte,br
# Processing Record 33 of Set 6 | upington,za
# Processing Record 34 of Set 6 | forbes,au
# Processing Record 35 of Set 6 | karratha,au
# Processing Record 36 of Set 6 | cartagena del chaira,co
# Processing Record 37 of Set 6 | ribeira brava,cv
# Processing Record 38 of Set 6 | kununurra,au
# Processing Record 39 of Set 6 | hithadhoo,mv
# Processing Record 40 of Set 6 | badger,us
# Processing Record 41 of Set 6 | mae chai,th
# Processing Record 42 of Set 6 | kuta,id
# Processing Record 43 of Set 6 | new norfolk,au
# Processing Record 44 of Set 6 | port alberni,ca
# Processing Record 45 of Set 6 | eidson road,us
# Processing Record 46 of Set 6 | dunedin,nz
# Processing Record 47 of Set 6 | crane,bb
# City crane,bb not found. Skipping...
# Processing Record 48 of Set 6 | perry,us
# Processing Record 49 of Set 6 | minusinsk,ru
# Processing Record 50 of Set 6 | cole harbour,ca
# Processing Record 1 of Set 7 | tortum,tr
# Processing Record 2 of Set 7 | nyandoma,ru
# Processing Record 3 of Set 7 | sitia,gr
# Processing Record 4 of Set 7 | ribeira grande,pt
# Processing Record 5 of Set 7 | flying fish cove,cx
# Processing Record 6 of Set 7 | san antonio oeste,ar
# Processing Record 7 of Set 7 | karaj,ir
# Processing Record 8 of Set 7 | silver lakes,us
# City silver lakes,us not found. Skipping...
# Processing Record 9 of Set 7 | inirida,co
# Processing Record 10 of Set 7 | el granada,us
# Processing Record 11 of Set 7 | sonsorol village,pw
# City sonsorol village,pw not found. Skipping...
# Processing Record 12 of Set 7 | turpan,cn
# Processing Record 13 of Set 7 | yuzhno-kurilsk,ru
# Processing Record 14 of Set 7 | batumi,ge
# Processing Record 15 of Set 7 | ozalp,tr
# Processing Record 16 of Set 7 | longquan,cn
# Processing Record 17 of Set 7 | khairagarh,in
# Processing Record 18 of Set 7 | aykhal,ru
# Processing Record 19 of Set 7 | priozersk,kz
# Processing Record 20 of Set 7 | sao vicente,pt
# Processing Record 21 of Set 7 | ribeira brava,pt
# Processing Record 22 of Set 7 | tegueste,es
# Processing Record 23 of Set 7 | yayva,ru
# Processing Record 24 of Set 7 | xingcheng,cn
# Processing Record 25 of Set 7 | antsiranana,mg
# Processing Record 26 of Set 7 | farrukhnagar,in
# Processing Record 27 of Set 7 | port lincoln,au
# Processing Record 28 of Set 7 | kyren,ru
# Processing Record 29 of Set 7 | ust-nera,ru
# Processing Record 30 of Set 7 | carnarvon,au
# Processing Record 31 of Set 7 | iskateley,ru
# Processing Record 32 of Set 7 | puerto baquerizo moreno,ec
# Processing Record 33 of Set 7 | san patricio,mx
# Processing Record 34 of Set 7 | nova sintra,cv
# Processing Record 35 of Set 7 | severo-yeniseyskiy,ru
# Processing Record 36 of Set 7 | kyelang,in
# Processing Record 37 of Set 7 | jacksonville,us
# Processing Record 38 of Set 7 | tual,id
# Processing Record 39 of Set 7 | swan hill,au
# Processing Record 40 of Set 7 | zhanaozen,kz
# Processing Record 41 of Set 7 | al ghayzah,ye
# Processing Record 42 of Set 7 | salacgriva,lv
# Processing Record 43 of Set 7 | yangor,nr
# City yangor,nr not found. Skipping...
# Processing Record 44 of Set 7 | al jawf,ly
# Processing Record 45 of Set 7 | gariadhar,in
# Processing Record 46 of Set 7 | ruteng,id
# Processing Record 47 of Set 7 | ma'rib,ye
# Processing Record 48 of Set 7 | merizo village,gu
# Processing Record 49 of Set 7 | kruisfontein,za
# Processing Record 50 of Set 7 | ayorou,ne
# Processing Record 1 of Set 8 | chortkiv,ua
# Processing Record 2 of Set 8 | fort bragg,us
# Processing Record 3 of Set 8 | mersing,my
# Processing Record 4 of Set 8 | youssoufia,ma
# Processing Record 5 of Set 8 | bocaiuva,br
# Processing Record 6 of Set 8 | kaoma,zm
# Processing Record 7 of Set 8 | igreja,cv
# Processing Record 8 of Set 8 | usinsk,ru
# Processing Record 9 of Set 8 | konarka,in
# Processing Record 10 of Set 8 | ingeniero luis a. huergo,ar
# Processing Record 11 of Set 8 | rastede,de
# Processing Record 12 of Set 8 | nadi,fj
# Processing Record 13 of Set 8 | burang,cn
# Processing Record 14 of Set 8 | baskil,tr
# Processing Record 15 of Set 8 | costa teguise,es
# City costa teguise,es not found. Skipping...
# Processing Record 16 of Set 8 | kalabo,zm
# Processing Record 17 of Set 8 | dryden,ca
# Processing Record 18 of Set 8 | luumaki,fi
# Processing Record 19 of Set 8 | boyabat,tr
# Processing Record 20 of Set 8 | banda aceh,id
# Processing Record 21 of Set 8 | ipua,br
# Processing Record 22 of Set 8 | renk,ss
# City renk,ss not found. Skipping...
# Processing Record 23 of Set 8 | kaltungo,ng
# Processing Record 24 of Set 8 | taro,sb
# City taro,sb not found. Skipping...
# Processing Record 25 of Set 8 | xai-xai,mz
# Processing Record 26 of Set 8 | vedaraniyam,in
# Processing Record 27 of Set 8 | chita,ru
# Processing Record 28 of Set 8 | puerto lempira,hn
# Processing Record 29 of Set 8 | inarajan village,gu
# Processing Record 30 of Set 8 | sisimiut,gl
# Processing Record 31 of Set 8 | yoichi,jp
# Processing Record 32 of Set 8 | sao jose da coroa grande,br
# Processing Record 33 of Set 8 | labytnangi,ru
# Processing Record 34 of Set 8 | huarmey,pe
# Processing Record 35 of Set 8 | bardai,td
# City bardai,td not found. Skipping...
# Processing Record 36 of Set 8 | al hawatah,sd
# Processing Record 37 of Set 8 | guerrero negro,mx
# Processing Record 38 of Set 8 | kijang,id
# Processing Record 39 of Set 8 | hobyo,so
# Processing Record 40 of Set 8 | chicxulub puerto,mx
# City chicxulub puerto,mx not found. Skipping...
# Processing Record 41 of Set 8 | lompoc,us
# Processing Record 42 of Set 8 | happy valley-goose bay,ca
# Processing Record 43 of Set 8 | brookings,us
# Processing Record 44 of Set 8 | constantia,za
# Processing Record 45 of Set 8 | krasnaya yaruga,ru
# Processing Record 46 of Set 8 | alaghsas,ne
# Processing Record 47 of Set 8 | lata,sb
# City lata,sb not found. Skipping...
# Processing Record 48 of Set 8 | yuzha,ru
# Processing Record 49 of Set 8 | kiliya,ua
# Processing Record 50 of Set 8 | mitsamiouli,km
# Processing Record 1 of Set 9 | chimoio,mz
# Processing Record 2 of Set 9 | ubinskoye,ru
# Processing Record 3 of Set 9 | portland,au
# Processing Record 4 of Set 9 | poltavka,ru
# Processing Record 5 of Set 9 | puerto deseado,ar
# Processing Record 6 of Set 9 | san antonio del estrecho,pe
# City san antonio del estrecho,pe not found. Skipping...
# Processing Record 7 of Set 9 | pago pago,as
# Processing Record 8 of Set 9 | olinda,br
# Processing Record 9 of Set 9 | coweta,us
# Processing Record 10 of Set 9 | rakops,bw
# Processing Record 11 of Set 9 | cape coast,gh
# Processing Record 12 of Set 9 | san pedro martir,mx
# Processing Record 13 of Set 9 | saint-francois,gp
# Processing Record 14 of Set 9 | rukban,jo
# City rukban,jo not found. Skipping...
# Processing Record 15 of Set 9 | manay,ph
# Processing Record 16 of Set 9 | qaqortoq,gl
# Processing Record 17 of Set 9 | igarka,ru
# Processing Record 18 of Set 9 | pastos bons,br
# Processing Record 19 of Set 9 | seogwipo,kr
# City seogwipo,kr not found. Skipping...
# Processing Record 20 of Set 9 | hasaki,jp
# Processing Record 21 of Set 9 | crucecita,mx
# City crucecita,mx not found. Skipping...
# Processing Record 22 of Set 9 | nabari,jp
# Processing Record 23 of Set 9 | tocopilla,cl
# Processing Record 24 of Set 9 | taltal,cl
# Processing Record 25 of Set 9 | macapa,br
# Processing Record 26 of Set 9 | qinggang,cn
# Processing Record 27 of Set 9 | bonthe,sl
# Processing Record 28 of Set 9 | dhidhdhoo,mv
# Processing Record 29 of Set 9 | jwaneng,bw
# Processing Record 30 of Set 9 | puerto aysen,cl
# Processing Record 31 of Set 9 | bel ombre,sc
# Processing Record 32 of Set 9 | bodaybo,ru
# Processing Record 33 of Set 9 | jinchang,cn
# Processing Record 34 of Set 9 | ryotsu-minato,jp
# Processing Record 35 of Set 9 | khalkhal,ir
# Processing Record 36 of Set 9 | saint croix,vi
# Processing Record 37 of Set 9 | chinde,mz
# City chinde,mz not found. Skipping...
# Processing Record 38 of Set 9 | mae ramat,th
# Processing Record 39 of Set 9 | port isabel,us
# Processing Record 40 of Set 9 | ghat,ly
# Processing Record 41 of Set 9 | mozarlandia,br
# Processing Record 42 of Set 9 | forster,au
# Processing Record 43 of Set 9 | qom,ir
# Processing Record 44 of Set 9 | vingt cinq,mu
# City vingt cinq,mu not found. Skipping...
# Processing Record 45 of Set 9 | sultanah,sa
# Processing Record 46 of Set 9 | tosontsengel,mn
# Processing Record 47 of Set 9 | wynne,us
# Processing Record 48 of Set 9 | san pascual,ph
# Processing Record 49 of Set 9 | ijuw,nr
# City ijuw,nr not found. Skipping...
# Processing Record 50 of Set 9 | slave lake,ca
# Processing Record 1 of Set 10 | st. john's,ca
# Processing Record 2 of Set 10 | newnham,au
# Processing Record 3 of Set 10 | murun-kuren,mn
# Processing Record 4 of Set 10 | anloga,gh
# Processing Record 5 of Set 10 | damascus,us
# Processing Record 6 of Set 10 | medina,sa
# Processing Record 7 of Set 10 | calvinia,za
# Processing Record 8 of Set 10 | la'ie,us
# Processing Record 9 of Set 10 | hwange,zw
# Processing Record 10 of Set 10 | san julian,bo
# Processing Record 11 of Set 10 | kayangel,pw
# Processing Record 12 of Set 10 | howard springs,au
# Processing Record 13 of Set 10 | sungai penuh,id
# Processing Record 14 of Set 10 | fontanelas,pt
# Processing Record 15 of Set 10 | jasper,us
# Processing Record 16 of Set 10 | katra,in
# Processing Record 17 of Set 10 | varoska rijeka,ba
# Processing Record 18 of Set 10 | turaif,sa
# Processing Record 19 of Set 10 | okha,ru
# Processing Record 20 of Set 10 | sumbawa besar,id
# Processing Record 21 of Set 10 | thunder bay,ca
# Processing Record 22 of Set 10 | alibag,in
# Processing Record 23 of Set 10 | mirnyy,ru
# Processing Record 24 of Set 10 | kosmach,ua
# Processing Record 25 of Set 10 | tazacorte,es
# Processing Record 26 of Set 10 | mejit,mh
# Processing Record 27 of Set 10 | yantarnyy,ru
# Processing Record 28 of Set 10 | kodinsk,ru
# Processing Record 29 of Set 10 | luau,ao
# Processing Record 30 of Set 10 | cambria,us
# Processing Record 31 of Set 10 | vilyuysk,ru
# Processing Record 32 of Set 10 | ust'-ilimsk,ru
# Processing Record 33 of Set 10 | wanning,cn
# Processing Record 34 of Set 10 | mirny,ru
# Processing Record 35 of Set 10 | vernon,ca
# Processing Record 36 of Set 10 | kyzyl-mazhalyk,ru
# Processing Record 37 of Set 10 | dedza,mw
# Processing Record 38 of Set 10 | jayapura,id
# Processing Record 39 of Set 10 | simpang,id
# Processing Record 40 of Set 10 | tromso,no
# Processing Record 41 of Set 10 | bandarbeyla,so
# Processing Record 42 of Set 10 | guidel-plage,fr
# Processing Record 43 of Set 10 | atvidaberg,se
# Processing Record 44 of Set 10 | hami,cn
# Processing Record 45 of Set 10 | guanare,ve
# Processing Record 46 of Set 10 | benguela,ao
# Processing Record 47 of Set 10 | wynyard,au
# Processing Record 48 of Set 10 | cockburn town,tc
# Processing Record 49 of Set 10 | ta`u,as
# Processing Record 50 of Set 10 | nagqu,cn
# Processing Record 1 of Set 11 | yeniseysk,ru
# Processing Record 2 of Set 11 | carbonear,ca
# Processing Record 3 of Set 11 | mount gambier,au
# Processing Record 4 of Set 11 | cabedelo,br
# Processing Record 5 of Set 11 | chake chake,tz
# Processing Record 6 of Set 11 | zhangatas,kz
# Processing Record 7 of Set 11 | kharkhorin,mn
# Processing Record 8 of Set 11 | ataq,ye
# Processing Record 9 of Set 11 | namibe,ao
# Processing Record 10 of Set 11 | sosnovoborsk,ru
# Processing Record 11 of Set 11 | naracoorte,au
# Processing Record 12 of Set 11 | taoudenni,ml
# Processing Record 13 of Set 11 | brisas de zicatela,mx
# Processing Record 14 of Set 11 | balqash,kz
# Processing Record 15 of Set 11 | amga,ru
# Processing Record 16 of Set 11 | pathein,mm
# Processing Record 17 of Set 11 | vicksburg,us
# Processing Record 18 of Set 11 | leo,bf
# Processing Record 19 of Set 11 | amuntai,id
# Processing Record 20 of Set 11 | enriquillo,do
# Processing Record 21 of Set 11 | nangis,fr
# Processing Record 22 of Set 11 | kawthoung,mm
# City kawthoung,mm not found. Skipping...
# Processing Record 23 of Set 11 | scone,au
# Processing Record 24 of Set 11 | cosesti,ro
# Processing Record 25 of Set 11 | port macquarie,au
# Processing Record 26 of Set 11 | dwarka,in
# Processing Record 27 of Set 11 | borogontsy,ru
# Processing Record 28 of Set 11 | mandera,ke
# Processing Record 29 of Set 11 | beijing,cn
# Processing Record 30 of Set 11 | muravlenko,ru
# Processing Record 31 of Set 11 | itoman,jp
# Processing Record 32 of Set 11 | anibare,nr
# City anibare,nr not found. Skipping...
# Processing Record 33 of Set 11 | weno,fm
# Processing Record 34 of Set 11 | tutong,bn
# Processing Record 35 of Set 11 | suntar,ru
# Processing Record 36 of Set 11 | kailua-kona,us
# Processing Record 37 of Set 11 | jesup,us
# Processing Record 38 of Set 11 | bengkulu,id
# Processing Record 39 of Set 11 | tanumah,sa
# Processing Record 40 of Set 11 | masterton,nz
# Processing Record 41 of Set 11 | nantucket,us
# Processing Record 42 of Set 11 | huedin,ro
# Processing Record 43 of Set 11 | saint-philippe,re
# Processing Record 44 of Set 11 | khanty-mansiysk,ru
# Processing Record 45 of Set 11 | bentiu,ss
# Processing Record 46 of Set 11 | shingu,jp
# Processing Record 47 of Set 11 | mabaruma,gy
# Processing Record 48 of Set 11 | nenjiang,cn
# Processing Record 49 of Set 11 | calingasta,ar
# Processing Record 50 of Set 11 | gobabis,na
# Processing Record 1 of Set 12 | caorle,it
# Processing Record 2 of Set 12 | pandan,ph
# Processing Record 3 of Set 12 | popayan,co
# Processing Record 4 of Set 12 | san borja,bo
# Processing Record 5 of Set 12 | horn,at
# Processing Record 6 of Set 12 | antalaha,mg
# Processing Record 7 of Set 12 | tafuna,as
# Processing Record 8 of Set 12 | mukalla,ye
# Processing Record 9 of Set 12 | tikapur,np
# Processing Record 10 of Set 12 | jiayuguan,cn
# Processing Record 11 of Set 12 | sao miguel do araguaia,br
# Processing Record 12 of Set 12 | san luis,mx
# Processing Record 13 of Set 12 | fedorovskiy,ru
# Processing Record 14 of Set 12 | salou,es
# Processing Record 15 of Set 12 | colonia,fm
# Processing Record 16 of Set 12 | ventspils,lv
# Processing Record 17 of Set 12 | sekong,la
# City sekong,la not found. Skipping...
# Processing Record 18 of Set 12 | santa ana,ph
# Processing Record 19 of Set 12 | cestos city,lr
# Processing Record 20 of Set 12 | dhuusamarreeb,so
# Processing Record 21 of Set 12 | vila do maio,cv
# Processing Record 22 of Set 12 | murghob,tj
# Processing Record 23 of Set 12 | cannonvale,au
# Processing Record 24 of Set 12 | mooloolaba,au
# Processing Record 25 of Set 12 | shani,ng
# Processing Record 26 of Set 12 | obo,cf
# Processing Record 27 of Set 12 | corner brook,ca
# Processing Record 28 of Set 12 | mar del plata,ar
# Processing Record 29 of Set 12 | luwuk,id
# Processing Record 30 of Set 12 | tadmur,sy
# Processing Record 31 of Set 12 | the pas,ca
# Processing Record 32 of Set 12 | montepuez,mz
# Processing Record 33 of Set 12 | tamanrasset,dz
# Processing Record 34 of Set 12 | zakynthos,gr
# Processing Record 35 of Set 12 | dogondoutchi,ne
# Processing Record 36 of Set 12 | turinsk,ru
# Processing Record 37 of Set 12 | coquimbo,cl
# Processing Record 38 of Set 12 | swakopmund,na
# Processing Record 39 of Set 12 | urumqi,cn
# Processing Record 40 of Set 12 | baluntaicun,cn
# City baluntaicun,cn not found. Skipping...
# Processing Record 41 of Set 12 | palmer,us
# Processing Record 42 of Set 12 | soio,ao
# Processing Record 43 of Set 12 | alto barinas,ve
# Processing Record 44 of Set 12 | havre,us
# Processing Record 45 of Set 12 | akureyri,is
# Processing Record 46 of Set 12 | malvan,in
# Processing Record 47 of Set 12 | castillos,uy
# Processing Record 48 of Set 12 | guanica,pr
# Processing Record 49 of Set 12 | paka,my
# Processing Record 50 of Set 12 | harper,lr
# Processing Record 1 of Set 13 | arkalyk,kz
# Processing Record 2 of Set 13 | cobija,bo
# Processing Record 3 of Set 13 | dukhan,qa
# Processing Record 4 of Set 13 | bunia,cd
# Processing Record 5 of Set 13 | eastham,us
# Processing Record 6 of Set 13 | rasulnagar,pk
# Processing Record 7 of Set 13 | mammoth lakes,us
# Processing Record 8 of Set 13 | homer,us
# Processing Record 9 of Set 13 | saynshand,mn
# Processing Record 10 of Set 13 | pangody,ru
# Processing Record 11 of Set 13 | eyl,so
# Processing Record 12 of Set 13 | meinerzhagen,de
# Processing Record 13 of Set 13 | sena madureira,br
# Processing Record 14 of Set 13 | chom bueng,th
# Processing Record 15 of Set 13 | gedo,et
# Processing Record 16 of Set 13 | srivardhan,in
# Processing Record 17 of Set 13 | bodo,no
# Processing Record 18 of Set 13 | vega de alatorre,mx
# Processing Record 19 of Set 13 | ulsteinvik,no
# Processing Record 20 of Set 13 | bikenibeu village,ki
# Processing Record 21 of Set 13 | aldan,ru
# Processing Record 22 of Set 13 | nema,mr
# Processing Record 23 of Set 13 | taksimo,ru
# Processing Record 24 of Set 13 | kakching,in
# Processing Record 25 of Set 13 | nyurba,ru
# Processing Record 26 of Set 13 | posto fiscal rolim de moura,br
# Processing Record 27 of Set 13 | arraial do cabo,br
# Processing Record 28 of Set 13 | sydney,ca
# Processing Record 29 of Set 13 | quellon,cl
# Processing Record 30 of Set 13 | sydney mines,ca
# Processing Record 31 of Set 13 | bayan nur,cn
# City bayan nur,cn not found. Skipping...
# Processing Record 32 of Set 13 | tambura,ss
# Processing Record 33 of Set 13 | haiku-pauwela,us
# Processing Record 34 of Set 13 | ha'il,sa
# Processing Record 35 of Set 13 | cadale,so
# Processing Record 36 of Set 13 | gamba,ga
# Processing Record 37 of Set 13 | pangai,to
# Processing Record 38 of Set 13 | bavly,ru
# Processing Record 39 of Set 13 | thief river falls,us
# Processing Record 40 of Set 13 | kegen,kz
# Processing Record 41 of Set 13 | lancaster,us
# Processing Record 42 of Set 13 | thinadhoo,mv
# Processing Record 43 of Set 13 | kourou,gf
# Processing Record 44 of Set 13 | thohoyandou,za
# Processing Record 45 of Set 13 | el idrissia,dz
# Processing Record 46 of Set 13 | emporia,us
# Processing Record 47 of Set 13 | qorveh,ir
# Processing Record 48 of Set 13 | cesky krumlov,cz
# Processing Record 49 of Set 13 | ash shafa,sa
# City ash shafa,sa not found. Skipping...
# Processing Record 50 of Set 13 | khouribga,ma
# Processing Record 1 of Set 14 | north bend,us
# Processing Record 2 of Set 14 | bourbon-lancy,fr
# Processing Record 3 of Set 14 | jodhpur,in
# Processing Record 4 of Set 14 | haflong,in
# Processing Record 5 of Set 14 | santa cruz,cr
# Processing Record 6 of Set 14 | bahia de caraquez,ec
# Processing Record 7 of Set 14 | santa elena,ec
# Processing Record 8 of Set 14 | camana,pe
# Processing Record 9 of Set 14 | sabang,id
# Processing Record 10 of Set 14 | rio grande,ar
# Processing Record 11 of Set 14 | cova figueira,cv
# Processing Record 12 of Set 14 | pitea,se
# Processing Record 13 of Set 14 | freeport,us
# Processing Record 14 of Set 14 | hailun,cn
# Processing Record 15 of Set 14 | rincon de nicolas romero (cedros tercera manzana),mx
# City rincon de nicolas romero (cedros tercera manzana),mx not found. Skipping...
# Processing Record 16 of Set 14 | anzio,it
# Processing Record 17 of Set 14 | bilsanda,in
# Processing Record 18 of Set 14 | rovaniemi,fi
# Processing Record 19 of Set 14 | alice springs,au
# Processing Record 20 of Set 14 | tucuma,br
# Processing Record 21 of Set 14 | black point,bs
# City black point,bs not found. Skipping...
# Processing Record 22 of Set 14 | lodja,cd
# Processing Record 23 of Set 14 | hradyz'k,ua
# Processing Record 24 of Set 14 | hollister,us
# Processing Record 25 of Set 14 | pekan,my
# Processing Record 26 of Set 14 | talara,pe
# Processing Record 27 of Set 14 | ojinaga,mx
# Processing Record 28 of Set 14 | buri,br
# Processing Record 29 of Set 14 | los chavez,us
# Processing Record 30 of Set 14 | mount isa,au
# Processing Record 31 of Set 14 | al kharijah,eg
# Processing Record 32 of Set 14 | chegdomyn,ru
# Processing Record 33 of Set 14 | priob'ye,ru
# Processing Record 34 of Set 14 | luena,ao
# Processing Record 35 of Set 14 | manaure,co
# Processing Record 36 of Set 14 | newman,au
# Processing Record 37 of Set 14 | i-n-salah,dz
# Processing Record 38 of Set 14 | kousseri,cm
# Processing Record 39 of Set 14 | tionk essil,sn
# Processing Record 40 of Set 14 | faya-largeau,td
# Processing Record 41 of Set 14 | karyes,gr
# Processing Record 42 of Set 14 | smithers,ca
# Processing Record 43 of Set 14 | borkum,de
# Processing Record 44 of Set 14 | dakoro,ne
# Processing Record 45 of Set 14 | san fernando de apure,ve
# Processing Record 46 of Set 14 | linhai,cn
# Processing Record 47 of Set 14 | novyy urengoy,ru
# Processing Record 48 of Set 14 | tyup,kg
# Processing Record 49 of Set 14 | muli,mv
# Processing Record 50 of Set 14 | sargans,ch
# Processing Record 1 of Set 15 | murzuq,ly
# Processing Record 2 of Set 15 | tamarin,mu
# Processing Record 3 of Set 15 | vila velha,br
# Processing Record 4 of Set 15 | turkestan,kz
# Processing Record 5 of Set 15 | zhangye,cn
# Processing Record 6 of Set 15 | las lomitas,ar
# Processing Record 7 of Set 15 | portel,br
# Processing Record 8 of Set 15 | rioja,pe
# Processing Record 9 of Set 15 | fisterra,es
# Processing Record 10 of Set 15 | ust-tsilma,ru
# Processing Record 11 of Set 15 | palikir - national government center,fm
# Processing Record 12 of Set 15 | manor,in
# Processing Record 13 of Set 15 | vryburg,za
# Processing Record 14 of Set 15 | laojunmiao,cn
# Processing Record 15 of Set 15 | maceio,br
# Processing Record 16 of Set 15 | aranda de duero,es
# Processing Record 17 of Set 15 | caratinga,br
# Processing Record 18 of Set 15 | labrador city,ca
# Processing Record 19 of Set 15 | kanel,sn
# Processing Record 20 of Set 15 | ar ruways,ae
# Processing Record 21 of Set 15 | pimentel,pe
# Processing Record 22 of Set 15 | itumbiara,br
# Processing Record 23 of Set 15 | king of prussia,us
# Processing Record 24 of Set 15 | gizo,sb
# Processing Record 25 of Set 15 | mulayjah,sa
# Processing Record 26 of Set 15 | sedan,fr
# Processing Record 27 of Set 15 | jumla,np
# Processing Record 28 of Set 15 | debre sina,et
# Processing Record 29 of Set 15 | sungho 1-tong,kp
# Processing Record 30 of Set 15 | new plymouth,nz
# Processing Record 31 of Set 15 | bafoulabe,ml
# Processing Record 32 of Set 15 | reggane,dz
# Processing Record 33 of Set 15 | kalamunda,au
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 690

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                           City      Lat       Lng  Max Temp  \
# 0                        Tiksi  71.6872  128.8694     38.73
# 1                       Albany -35.0169  117.8917     55.45
# 2                     Usogorsk  63.4106   48.6872     47.25
# 3                      Tsiombe -25.3000   45.4833     65.88
# 4            Port-aux-Français -49.3500   70.2167     41.18
# 5              Lázaro Cárdenas  17.9583 -102.2000     85.71
# 6                      Dudinka  69.4058   86.1778     43.54
# 7  Edinburgh of the Seven Seas -37.0676  -12.3116     57.15
# 8                      Ushuaia -54.8000  -68.3000     44.26
# 9                    Grytviken -54.2811  -36.5092     33.98
#
#   Current Description  Humidity  Cloudiness  Wind Speed Country
# 0       broken clouds        86          70        2.35      RU
# 1       broken clouds        65          79        6.22      AU
# 2           clear sky        74          10        4.43      RU
# 3       broken clouds        69          59        5.77      MG
# 4    scattered clouds        80          46       30.38      TF
# 5           clear sky        55           0       12.86      MX
# 6          light rain        88         100       24.61      RU
# 7       broken clouds        69          84       15.88      SH
# 8          light rain        87          75       11.50      AR
# 9    scattered clouds        93          43        1.50      GS

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#                           City Country      Lat       Lng  Max Temp  Humidity  \
# 0                        Tiksi      RU  71.6872  128.8694     38.73        86
# 1                       Albany      AU -35.0169  117.8917     55.45        65
# 2                     Usogorsk      RU  63.4106   48.6872     47.25        74
# 3                      Tsiombe      MG -25.3000   45.4833     65.88        69
# 4            Port-aux-Français      TF -49.3500   70.2167     41.18        80
# 5              Lázaro Cárdenas      MX  17.9583 -102.2000     85.71        55
# 6                      Dudinka      RU  69.4058   86.1778     43.54        88
# 7  Edinburgh of the Seven Seas      SH -37.0676  -12.3116     57.15        69
# 8                      Ushuaia      AR -54.8000  -68.3000     44.26        87
# 9                    Grytviken      GS -54.2811  -36.5092     33.98        93
#
#    Cloudiness  Wind Speed Current Description
# 0          70        2.35       broken clouds
# 1          79        6.22       broken clouds
# 2          10        4.43           clear sky
# 3          59        5.77       broken clouds
# 4          46       30.38    scattered clouds
# 5           0       12.86           clear sky
# 6         100       24.61          light rain
# 7          84       15.88       broken clouds
# 8          75       11.50          light rain
# 9          43        1.50    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
outfile = "Weather_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(outfile, index_label="City_ID")
